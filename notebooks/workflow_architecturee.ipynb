# %% [markdown]
# +-------------------------------------------------------------------------+
# |                         LANGGRAPH WORKFLOW                              |
# |                                                                         |
# |  +-------+    +------------+    +-----------------------+               |
# |  | INPUT |--> | PREPROCESS |--> | PREDICT NODE          |               |
# |  | NODE  |    | NODE       |    | (XGBoost .pkl)        |               |
# |  +-------+    +------------+    +-----------------------+               |
# |                                            |                            |
# |                                            v                            |
# |                                 +-----------------------+               |
# |                                 | ROUTER NODE           |               |
# |                                 | (Conditional Edge)    |               |
# |                                 +-----------------------+               |
# |                                     |               |                   |
# |                          churn=True |               | churn=False       |
# |                                     v               v                   |
# |                      +----------------+   +----------------+            |
# |                      | CHURN          |   | RETENTION      |            |
# |                      | PREVENTION     |   | ENHANCE        |            |
# |                      | AGENT          |   | AGENT          |            |
# |                      +----------------+   +----------------+            |
# |                                     |               |                   |
# |                                     v               v                   |
# |                                 +-----------------------+               |
# |                                 | RESPONSE FORMATTER    |               |
# |                                 | (Structured Output    |               |
# |                                 |  Node)                |               |
# |                                 +-----------------------+               |
# |                                            |                            |
# |                                            v                            |
# |                                       +--------+                        |
# |                                       | OUTPUT |                        |
# |                                       | NODE   |                        |
# |                                       +--------+                        |
# +-------------------------------------------------------------------------+
